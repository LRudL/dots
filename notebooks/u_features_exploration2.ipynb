# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append("..")
import os
import math
import numpy as np
import torch as t
import torch.utils.data as tdata
import matplotlib.pyplot as plt
from einops import rearrange
from dots.training import *
from dots.trainhooks import *
from dots.models import MLP
from dots.dots import *
from dots.utils import *
from dots.plotting import *
from dots.experiment import get_train_state, get_config_dataset
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Simple test of plotting during training

# %%
ts = get_train_state("../configs/models/mlp-relu-good.yml")
ds = tensor_of_dataset(get_config_dataset("../configs/models/mlp-relu-good.yml"))

# %% [markdown]
# ## Start of training

# %%
plot_1d_u_feats(ts.model, range_batch(-1, 1, 500, sort=True))
# Out:
# /home/lrudl/miniconda3/envs/dots_env/lib/python3.10/site-packages/torch/nn/utils/stateless.py:216: UserWarning: This API is deprecated as of PyTorch 2.0 and will be removed in a future version of PyTorch. Please use torch.func.functional_call instead which is a drop-in replacement for this API.
#   warnings.warn(
# /home/lrudl/Dropbox/Rudolf/Cambridge/22-23/dots/dots/notebooks/../dots/plotting.py:105: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   x = range_batch(start, end, n)

# %%
plot_1d_fn(ts.model)
# Out:
# /home/lrudl/Dropbox/Rudolf/Cambridge/22-23/dots/dots/notebooks/../dots/plotting.py:32: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   given_ax = ax

# %% [markdown]
# ## Train

# %%
ts.train(epochs=30)
# Out:
# /home/lrudl/miniconda3/envs/dots_env/lib/python3.10/site-packages/torch/nn/utils/stateless.py:216: UserWarning: This API is deprecated as of PyTorch 2.0 and will be removed in a future version of PyTorch. Please use torch.func.functional_call instead which is a drop-in replacement for this API.
#   warnings.warn(

# %%
ts.plot()
# Out:
# /home/lrudl/Dropbox/Rudolf/Cambridge/22-23/dots/dots/notebooks/../dots/training.py:258: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
plot_1d_fn(ts.model)
# Out:
# /home/lrudl/Dropbox/Rudolf/Cambridge/22-23/dots/dots/notebooks/../dots/plotting.py:32: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   given_ax = ax

# %% [markdown]
# ## After training

# %%
plot_1d_u_feats(ts.model, range_batch(-1, 1, 500, sort=True))
# Out:
# /home/lrudl/miniconda3/envs/dots_env/lib/python3.10/site-packages/torch/nn/utils/stateless.py:216: UserWarning: This API is deprecated as of PyTorch 2.0 and will be removed in a future version of PyTorch. Please use torch.func.functional_call instead which is a drop-in replacement for this API.
#   warnings.warn(
# /home/lrudl/Dropbox/Rudolf/Cambridge/22-23/dots/dots/notebooks/../dots/plotting.py:105: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   x = range_batch(start, end, n)

# %%
plot_1d_fn(ts.model)
# Out:
# /home/lrudl/Dropbox/Rudolf/Cambridge/22-23/dots/dots/notebooks/../dots/plotting.py:32: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   given_ax = ax

# %%
trainplot_1d(ts, ds, random_batch(1000, (1,)), range_batch(-1, 1, 1000))
# Out:
# /home/lrudl/miniconda3/envs/dots_env/lib/python3.10/site-packages/torch/nn/utils/stateless.py:216: UserWarning: This API is deprecated as of PyTorch 2.0 and will be removed in a future version of PyTorch. Please use torch.func.functional_call instead which is a drop-in replacement for this API.
#   warnings.warn(
# /home/lrudl/miniconda3/envs/dots_env/lib/python3.10/site-packages/torch/nn/utils/stateless.py:216: UserWarning: This API is deprecated as of PyTorch 2.0 and will be removed in a future version of PyTorch. Please use torch.func.functional_call instead which is a drop-in replacement for this API.
#   warnings.warn(
# /home/lrudl/miniconda3/envs/dots_env/lib/python3.10/site-packages/torch/nn/utils/stateless.py:216: UserWarning: This API is deprecated as of PyTorch 2.0 and will be removed in a future version of PyTorch. Please use torch.func.functional_call instead which is a drop-in replacement for this API.
#   warnings.warn(
# ...

# %%
ts.model.singular_value_rank(range_batch(-1, 1, 1000), method="heuristic")
# Out:
# /home/lrudl/miniconda3/envs/dots_env/lib/python3.10/site-packages/torch/nn/utils/stateless.py:216: UserWarning: This API is deprecated as of PyTorch 2.0 and will be removed in a future version of PyTorch. Please use torch.func.functional_call instead which is a drop-in replacement for this API.
#   warnings.warn(
# 1

# %% [markdown]
# # Sanity-checking saved models

# %%
model0 = load_model("olive-sweep-6_model_0", loc="out")

# %%
fig = trainplot_1d(model0, ds)
# Out:
# Assuming trainplot_1d got a model, not a trainstate
# /home/lrudl/miniconda3/envs/dots_env/lib/python3.10/site-packages/torch/nn/utils/stateless.py:216: UserWarning: This API is deprecated as of PyTorch 2.0 and will be removed in a future version of PyTorch. Please use torch.func.functional_call instead which is a drop-in replacement for this API.
#   warnings.warn(
# /home/lrudl/miniconda3/envs/dots_env/lib/python3.10/site-packages/torch/nn/utils/stateless.py:216: UserWarning: This API is deprecated as of PyTorch 2.0 and will be removed in a future version of PyTorch. Please use torch.func.functional_call instead which is a drop-in replacement for this API.
#   warnings.warn(
# /home/lrudl/miniconda3/envs/dots_env/lib/python3.10/site-packages/torch/nn/utils/stateless.py:216: UserWarning: This API is deprecated as of PyTorch 2.0 and will be removed in a future version of PyTorch. Please use torch.func.functional_call instead which is a drop-in replacement for this API.
# ...

# %%
model0b = get_train_state("../configs/models/mlp-sin-1.yml").model

# %%
fig = trainplot_1d(model0b, ds)
# Out:
# Assuming trainplot_1d got a model, not a trainstate
# /home/lrudl/miniconda3/envs/dots_env/lib/python3.10/site-packages/torch/nn/utils/stateless.py:216: UserWarning: This API is deprecated as of PyTorch 2.0 and will be removed in a future version of PyTorch. Please use torch.func.functional_call instead which is a drop-in replacement for this API.
#   warnings.warn(
# /home/lrudl/miniconda3/envs/dots_env/lib/python3.10/site-packages/torch/nn/utils/stateless.py:216: UserWarning: This API is deprecated as of PyTorch 2.0 and will be removed in a future version of PyTorch. Please use torch.func.functional_call instead which is a drop-in replacement for this API.
#   warnings.warn(
# /home/lrudl/miniconda3/envs/dots_env/lib/python3.10/site-packages/torch/nn/utils/stateless.py:216: UserWarning: This API is deprecated as of PyTorch 2.0 and will be removed in a future version of PyTorch. Please use torch.func.functional_call instead which is a drop-in replacement for this API.
# ...

# %%
from dots.models import *

# %%
mlp1 = MLP(1, 1, [100])
mlp1
# Out:
# MLP(
#   (layers): Sequential(
#     (0): Linear(in_features=1, out_features=100, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=100, out_features=1, bias=True)
#   )
# )

# %%
fig = trainplot_1d(mlp1)
# Out:
# Assuming trainplot_1d got a model, not a trainstate
# /home/lrudl/miniconda3/envs/dots_env/lib/python3.10/site-packages/torch/nn/utils/stateless.py:216: UserWarning: This API is deprecated as of PyTorch 2.0 and will be removed in a future version of PyTorch. Please use torch.func.functional_call instead which is a drop-in replacement for this API.
#   warnings.warn(
# /home/lrudl/miniconda3/envs/dots_env/lib/python3.10/site-packages/torch/nn/utils/stateless.py:216: UserWarning: This API is deprecated as of PyTorch 2.0 and will be removed in a future version of PyTorch. Please use torch.func.functional_call instead which is a drop-in replacement for this API.
#   warnings.warn(

# %%
fig = trainplot_1d(MLP(1, 1, [10, 10]))
# Out:
# Assuming trainplot_1d got a model, not a trainstate
# /home/lrudl/miniconda3/envs/dots_env/lib/python3.10/site-packages/torch/nn/utils/stateless.py:216: UserWarning: This API is deprecated as of PyTorch 2.0 and will be removed in a future version of PyTorch. Please use torch.func.functional_call instead which is a drop-in replacement for this API.
#   warnings.warn(
# /home/lrudl/miniconda3/envs/dots_env/lib/python3.10/site-packages/torch/nn/utils/stateless.py:216: UserWarning: This API is deprecated as of PyTorch 2.0 and will be removed in a future version of PyTorch. Please use torch.func.functional_call instead which is a drop-in replacement for this API.
#   warnings.warn(

# %%
fig = trainplot_1d(MLP(1, 1, [1000]))
# Out:
# Assuming trainplot_1d got a model, not a trainstate
# /home/lrudl/miniconda3/envs/dots_env/lib/python3.10/site-packages/torch/nn/utils/stateless.py:216: UserWarning: This API is deprecated as of PyTorch 2.0 and will be removed in a future version of PyTorch. Please use torch.func.functional_call instead which is a drop-in replacement for this API.
#   warnings.warn(
# /home/lrudl/miniconda3/envs/dots_env/lib/python3.10/site-packages/torch/nn/utils/stateless.py:216: UserWarning: This API is deprecated as of PyTorch 2.0 and will be removed in a future version of PyTorch. Please use torch.func.functional_call instead which is a drop-in replacement for this API.
#   warnings.warn(

# %%
fig = trainplot_1d(MLP(1, 1, [50]))
# Out:
# Assuming trainplot_1d got a model, not a trainstate
# /home/lrudl/miniconda3/envs/dots_env/lib/python3.10/site-packages/torch/nn/utils/stateless.py:216: UserWarning: This API is deprecated as of PyTorch 2.0 and will be removed in a future version of PyTorch. Please use torch.func.functional_call instead which is a drop-in replacement for this API.
#   warnings.warn(

# %%
MLP(1, 1, [1000]).count_params()
# Out:
# 3001

# %%
MLP(1, 1, [10, 10, 10, 10, 10, 10, 10, 10]).count_params()
# Out:
# 801

# %%
MLP(1, 1, [10, 10, 10, 10, 10, 10, 10, 10]).jacobian_singular_values(range_batch(-1, 1, 1000)).shape
# Out:
# /home/lrudl/miniconda3/envs/dots_env/lib/python3.10/site-packages/torch/nn/utils/stateless.py:216: UserWarning: This API is deprecated as of PyTorch 2.0 and will be removed in a future version of PyTorch. Please use torch.func.functional_call instead which is a drop-in replacement for this API.
#   warnings.warn(
# torch.Size([30])

# %%
fig = trainplot_1d(MLP(1, 1, [10, 10, 10]))
# Out:
# Assuming trainplot_1d got a model, not a trainstate
# /home/lrudl/miniconda3/envs/dots_env/lib/python3.10/site-packages/torch/nn/utils/stateless.py:216: UserWarning: This API is deprecated as of PyTorch 2.0 and will be removed in a future version of PyTorch. Please use torch.func.functional_call instead which is a drop-in replacement for this API.
#   warnings.warn(

# %%
fig = trainplot_1d(MLP(1, 1, [10, 10, 10, 10, 10, 10, 10, 10]))
# Out:
# Assuming trainplot_1d got a model, not a trainstate
# /home/lrudl/miniconda3/envs/dots_env/lib/python3.10/site-packages/torch/nn/utils/stateless.py:216: UserWarning: This API is deprecated as of PyTorch 2.0 and will be removed in a future version of PyTorch. Please use torch.func.functional_call instead which is a drop-in replacement for this API.
#   warnings.warn(
# /home/lrudl/miniconda3/envs/dots_env/lib/python3.10/site-packages/torch/nn/utils/stateless.py:216: UserWarning: This API is deprecated as of PyTorch 2.0 and will be removed in a future version of PyTorch. Please use torch.func.functional_call instead which is a drop-in replacement for this API.
#   warnings.warn(

# %%
svals= model0b.jacobian_singular_values(range_batch(-1, 1, 1000))

# %%
plt.plot(svals)
plt.yscale("log")
plt.axvline(model0b.jacobian_matrix_rank(range_batch(-1, 1, 1000)), color="red")
# Out:
# /home/lrudl/miniconda3/envs/dots_env/lib/python3.10/site-packages/torch/nn/utils/stateless.py:216: UserWarning: This API is deprecated as of PyTorch 2.0 and will be removed in a future version of PyTorch. Please use torch.func.functional_call instead which is a drop-in replacement for this API.
#   warnings.warn(

# %%
model0b.count_params()
# Out:
# 301

# %%
U, S, Vh = model0b.jacobian_svd(range_batch(-1, 1, 1000))

# %%
U.shape
# Out:
# torch.Size([1000, 301])

# %%
S.shape
# Out:
# torch.Size([301])

# %%
Vh.shape
# Out:
# torch.Size([301, 301])

# %%
model0b.jacobian_matrix_rank(range_batch(-1, 1, 1000))
# Out:
# /home/lrudl/miniconda3/envs/dots_env/lib/python3.10/site-packages/torch/nn/utils/stateless.py:216: UserWarning: This API is deprecated as of PyTorch 2.0 and will be removed in a future version of PyTorch. Please use torch.func.functional_call instead which is a drop-in replacement for this API.
#   warnings.warn(
# tensor(66)
